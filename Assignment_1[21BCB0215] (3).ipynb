# %%
import pandas as pd

# %% [markdown]
# ## Task - 1 Create a pandas dataframe (DataFrame name as 'df') (10 observation row and 5 features column)

# %%
df = pd.read_csv('/content/House Price India.csv')
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
from numpy import nan

d = {'FName':['James','Hazel','Luna','Tom','Jasper'],
     'MName':['J','H','L','T','J'],
     'LName':['Gil','Smith','Borg','Wong','Will'],
     'SSN':[123,456,789,147,258],
     'Age':[20,19,22,nan,18],
     'Gender':['M','F','F','M','M'],
     'Height':[175,160,155,170,172],
     'Salary':[88000,77000,99000,87000,89000],
     'DepNo':[1,2,3,4,5],
     'BDay':[6,19,1,14,23]}
d
# Out:
# {'FName': ['James', 'Hazel', 'Luna', 'Tom', 'Jasper'],
#  'MName': ['J', 'H', 'L', 'T', 'J'],
#  'LName': ['Gil', 'Smith', 'Borg', 'Wong', 'Will'],
#  'SSN': [123, 456, 789, 147, 258],
#  'Age': [20, 19, 22, nan, 18],
#  'Gender': ['M', 'F', 'F', 'M', 'M'],
#  'Height': [175, 160, 155, 170, 172],
#  'Salary': [88000, 77000, 99000, 87000, 89000],
#  'DepNo': [1, 2, 3, 4, 5],
#  'BDay': [6, 19, 1, 14, 23]}

# %%
df = pd.DataFrame(d)
df
# Out:
#     FName MName  LName  SSN   Age Gender  Height  Salary  DepNo  BDay
# 0   James     J    Gil  123  20.0      M     175   88000      1     6
# 1   Hazel     H  Smith  456  19.0      F     160   77000      2    19
# 2    Luna     L   Borg  789  22.0      F     155   99000      3     1
# 3     Tom     T   Wong  147   NaN      M     170   87000      4    14
# 4  Jasper     J   Will  258  18.0      M     172   89000      5    23

# %% [markdown]
# ## Task- 2 Check the info of 'df'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   FName   5 non-null      object
#  1   MName   5 non-null      object
#  2   LName   5 non-null      object
#  3   SSN     5 non-null      int64
#  4   Age     4 non-null      float64
#  5   Gender  5 non-null      object
#  6   Height  5 non-null      int64
#  7   Salary  5 non-null      int64
#  8   DepNo   5 non-null      int64
#  9   BDay    5 non-null      int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 528.0+ bytes

# %% [markdown]
# ## Task 3- Check the descriptive statistics of 'df'

# %%
df.describe()
# Out:
#               SSN        Age      Height        Salary     DepNo       BDay
# count    5.000000   4.000000    5.000000      5.000000  5.000000   5.000000
# mean   354.600000  19.750000  166.400000  88000.000000  3.000000  12.600000
# std    276.158107   1.707825    8.502941   7810.249676  1.581139   9.071935
# min    123.000000  18.000000  155.000000  77000.000000  1.000000   1.000000
# 25%    147.000000  18.750000  160.000000  87000.000000  2.000000   6.000000
# 50%    258.000000  19.500000  170.000000  88000.000000  3.000000  14.000000
# 75%    456.000000  20.500000  172.000000  89000.000000  4.000000  19.000000
# max    789.000000  22.000000  175.000000  99000.000000  5.000000  23.000000

# %% [markdown]
# ## Task 4- check the 4th index observation with 'loc' slicing operator.

# %%
df
# Out:
#     FName MName  LName  SSN   Age Gender  Height  Salary  DepNo  BDay
# 0   James     J    Gil  123  20.0      M     175   88000      1     6
# 1   Hazel     H  Smith  456  19.0      F     160   77000      2    19
# 2    Luna     L   Borg  789  22.0      F     155   99000      3     1
# 3     Tom     T   Wong  147   NaN      M     170   87000      4    14
# 4  Jasper     J   Will  258  18.0      M     172   89000      5    23

# %%
df.loc[4]
# Out:
# FName     Jasper
# MName          J
# LName       Will
# SSN          258
# Age         18.0
# Gender         M
# Height       172
# Salary     89000
# DepNo          5
# BDay          23
# Name: 4, dtype: object

# %% [markdown]
# ## Task 5 - Check the null values in your 'df'

# %%
df.isnull().any()
# Out:
# FName     False
# MName     False
# LName     False
# SSN       False
# Age        True
# Gender    False
# Height    False
# Salary    False
# DepNo     False
# BDay      False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# FName     0
# MName     0
# LName     0
# SSN       0
# Age       1
# Gender    0
# Height    0
# Salary    0
# DepNo     0
# BDay      0
# dtype: int64
